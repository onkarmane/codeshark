# %% [markdown]
# Steps :
# 1. Import Library
# 2. Take user input
# 3. Convert user input
# 4. Make operations

# %% [markdown]
# ![operations.png](attachment:operations.png)

# %%
import math

# %%
a = int(input("Enter Number : "))

# %%
b = int(input("Enter Number : "))

# %%
addition = a + b

# %%
addition

# %%
# ---------------------------------XXXXXXXXXXXXXXXXXXXXXXXXXXXXXX_-------------------------------------

# %%
c = int(input("Enter Number : "))

# %%
d = int(input("Enter Number : "))

# %%
subtraction = c - d

# %%
subtraction

# %%
#  Exercises

# %%
# Multliplication ,division,  exponential ....

# %%
# Extra trick

# %%
# taking two inputs at a time
x, y = input("Enter two values: ").split()

# %%
x

# %%
y

# %%
#What is type(x), type(y)

# %%
type(x)

# %%
#Convert type to another variable
